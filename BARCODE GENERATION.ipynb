# %%
import barcode
from barcode import Code128

# %%
def generate_barcode(data):
    code = Code128(data)
    code.save('barcode.png')
    print('BARCODE GENERATED')

data = '1234-5678-9012'
generate_barcode(data)
# Out:
# BARCODE GENERATED

# %%
from IPython.display import SVG

SVG(filename='barcode.svg')
